# %%
from model_loss_replaced import *
from data import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Train your Unet with membrane data
# membrane data is in folder membrane/, it is a binary classification task.
#
# The input shape of image and mask are the same :(batch_size,rows,cols,channel = 1)

# %% [markdown]
# ### Train with data generator

# %%
aug_args = dict(
    rotation_range = 0.2,
    width_shift_range = 0.05,
    height_shift_range = 0.05,
    shear_range = 0.05,
    zoom_range = 0.05,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

train_gene = trainGenerator(batch_size=2,aug_dict=aug_args,train_path='dataset/',
                        image_folder='image',label_folder='label',
                        image_color_mode='rgb',label_color_mode='rgb',
                        image_save_prefix='image',label_save_prefix='label',
                        flag_multi_class=True,save_to_dir=None)
#tensorboard = TensorBoard(log_dir='log/')
model = unet(num_class=4)
model_checkpoint = ModelCheckpoint('saved_model.hdf5',monitor='loss',verbose=1,save_best_only=True)

history = model.fit_generator(train_gene,
                              steps_per_epoch=2000,
                              epochs=10,
                              verbose=1,
                              callbacks=[model_checkpoint])
# Out:
# /home/jovyan/work/formal_multi_class/model_tversky_multi.py:84: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input= inputs,output=conv10)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ### test your model and save predicted results

# %%
test_gene = testGenerator(test_path='dataset/test')
model = unet(num_class=4)
model.load_weights("saved_model.hdf5")
results = model.predict_generator(test_gene,78,verbose=1)
saveResult('results',results)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 64) 36928       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_25[0][0]
# ...
